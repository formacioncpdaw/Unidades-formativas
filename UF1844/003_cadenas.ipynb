# %% [markdown]
# # Cadenas de texto

# %%
cadena = """ 
este es un texto largo
- punto 1: 'Comillas simples'
- punto 2: \"Comillas dobles\"
- punto 3
"""

print(len(cadena))
# Out:
# 94

# %%
larga = "Enrólate en la marina"
print(len(larga))
# Out:
# 21

# %% [markdown]
# ## Slicing

# %%
print(larga[::-1])
print(larga[3])
# Out:
# aniram al ne etalórnE
# ó

# %%
print('hola mundo')
# Out:
# hola mundo
