# %% [markdown]
# # Diccionarios
# ## Segundo
# ### Tercero
# Normal
# - sss
# - sss
# - sssss
# 1. es
# 2. mm
# 3. **ooo**

# %% [markdown]
# dicc = {
#     1: "Uno",
#     2: "Dos",
#     "nombre":  'Paco',
#     "apellido": 'Lopez',
#     ...
#
# }
#
# alumnos = [{
#     'nombre': 'María José',
#     'direccion': {
#         'calle': 'Sierpes',
#         'numero': '1',
#         'cp':'41001',
#         'telefonos': ['955123456', '600123887']
#     }
#
# },
# {
#     'nombre': 'Alejandro',
#     'direccion': {
#         'calle': 'Sierpes',
#         'numero': '1',
#         'cp':'41001',
#         'telefonos': ['955123456', '600123887']
#     }
# }
# ]

# %%
alumno1 ={
    'nombre': 'María José',
    'direccion': {
        'calle': 'Sierpes',
        'numero': '1',
        'cp':'41001',
        'telefonos': ['955123456', '600123887']
    }
}
alumno1['direccion']
direcc = alumno1['direccion']

# %%
direcc['telefonos']
# Out:
# ['955123456', '600123887']

# %%
otro = {}
otro['p1'] = 123
otro['p1'] = 0


complejo = {
        'calle': 'Sierpes',
        'numero': '1',
        'cp':'41001',
        'telefonos': ['955123456', '600123887']
    }
otro['p2'] = complejo

otro
# Out:
# {'p1': 0,
#  'p2': {'calle': 'Sierpes',
#   'numero': '1',
#   'cp': '41001',
#   'telefonos': ['955123456', '600123887']}}

# %%
otro.get('p11',"No hay nada")
# Out:
# 'No hay nada'

# %%
lorem = """
Lorem ipsum dolor sit amet consectetur adipisicing elit.
"""

frecuencias = {}

# for letra in lorem:
#     if frecuencias.get(letra,False):
#         frecuencias[letra] += 1
#     else:
#         frecuencias[letra] = 1

for letra in lorem:
    if frecuencias.get(letra):
        frecuencias[letra] += 1
    else:
        frecuencias[letra] = 1


# for letra in lorem:
#     if letra in frecuencias:
#         frecuencias[letra] += 1
#     else:
#         frecuencias[letra] = 1

from pprint import pprint
pprint(frecuencias)
# Out:
# {'\n': 2,
#  ' ': 7,
#  '.': 1,
#  'L': 1,
#  'a': 2,
#  'c': 3,
#  'd': 2,
#  'e': 5,
#  'g': 1,
#  'i': 7,
#  'l': 2,
#  'm': 3,
#  'n': 2,
#  'o': 4,
#  'p': 2,
#  'r': 3,
#  's': 4,
#  't': 5,
#  'u': 2}

# %%
claves = frecuencias.keys()
valores = frecuencias.values()
elementos = frecuencias.items()
elementos

# %%
for c in elementos:
    print(f'Clave: {c[0]}, Valor: {c[1]}')

# %%
otro = {
    1:'a',
    2:'b',
    3:'c',
    4:'d'
}
reves = {}
# for c in otro.items():
#     reves[c[1]] = c[0]

# reves

# %%
for k,v in otro.items(): 
    reves[v] = k

reves
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
consulta = [
    {'id':1, 'nombre':'dddd', 'apellido1':'uhuhuhu'},
    {}

]
# Out:
# False
