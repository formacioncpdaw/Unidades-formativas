# %% [markdown]
# # Introducción a Python
# Esta es una primera prueba

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
dia = "jueves"
type(dia)
# Out:
# str

# %%
dia = 4
type(dia)
# Out:
# int

# %%
cadena = int("1") + 2

# %%
cadena
# Out:
# 3

# %%
'Hola "hola" caracola'
# Out:
# 'Hola "hola" caracola'

# %%
cadena = "Alistate en la marina"

# %% [markdown]
# ## Slicing

# %%
cadena[::-1]
# Out:
# 'aniram al ne etatsilA'

# %%
nombre = 'Paco'
apellido = 'Lopez'
completo = nombre + " " + apellido
print(completo)
print(nombre)
# Out:
# Paco Lopez
# Paco

# %%
ruta = "C:\\Users\\Alumnos Tarde\\Desktop\\TEO_IFCD_0210\\IFCD0210\\UF1844"
print(ruta)
# Out:
# C:\Users\Alumnos Tarde\Desktop\TEO_IFCD_0210\IFCD0210\UF1844

# %% [markdown]
# ## Cadenas 'r' (raw)

# %%
ruta = r'C:\Users\Alumnos_Tarde\Desktop\TEO_IFCD_0210\IFCD0210\UF1844'
print(ruta)
# Out:
# C:\Users\Alumnos_Tarde\Desktop\TEO_IFCD_0210\IFCD0210\UF1844

# %% [markdown]
# ## Cadenas 'f' (format)

# %%
cadena_f = f'Mi nombre es {nombre} y mi apellido es {apellido}. Mi nombre completo es {completo[0:7]}'
print(cadena_f)
# Out:
# Mi nombre es Paco y mi apellido es Lopez. Mi nombre completo es Paco Lo

# %%
uno = 1
dos = 2
print(f'La suma es {uno / dos}')
# Out:
# La suma es 0.5

# %% [markdown]
# ## Condicionales

# %%
x = 2
if x > 5:
    print("Es mayor")
else:
    print('No es mayor')
# Out:
# No es mayor

# %%
dato = input("Dame un numerito")

numero = int(dato)
if numero > 0:
    print(f'El número {numero} es mayor que cero')
elif numero == 0:
    print(f'El número {numero} es cero')
else:
    print(f'El número {numero} es menor que cero')
# Out:
# El número 6 es mayor que cero

# %%
visitas_lab = 150
importe_lab = 637.50

visitas_fes = 250
precio_entrada = importe_lab / visitas_lab
importe_fes = visitas_fes * precio_entrada

print(importe_fes)
# Out:
# 1062.5

# %%
objetivo = 2125
vistantes_obj = objetivo / precio_entrada
print(vistantes_obj)
# Out:
# 500.0

# %%
cadena = "texto de prueba"
letra = input("Dime una letra")
if letra in cadena:
    print(f'La letra "{letra}" está en la cadena')
else:
    print(f'La letra "{letra}" NO está en la cadena')
# Out:
# La letra "P" NO está en la cadena

# %%
cadena = '1,2,3,4,5,6,7,8,9,0'
lista = cadena.split(',')

# %%
",".join(lista)
# Out:
# '1,2,3,4,5,6,7,8,9,0'

# %%
lista[::-1]
# Out:
# ['0', '9', '8', '7', '6', '5', '4', '3', '2', '1']

# %%
'1' in lista
# Out:
# True

# %% [markdown]
# ### Operadores

# %%
# Operador Módulo
16 % 9

# Operador división entera
16 // 9

12 // 5

# Operador exponente
3 ** 3

27 ** (1/3)
# Out:
# 3.0

# %%
x = 1
y = 5
z = 0

if 1 < z < 5: 
    pass

# %%
x = 2
x += 3 # x = x + 3
x *= 3 # x = x * 3
x //= 3



print(x)
# Out:
# 5
