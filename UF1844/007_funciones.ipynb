# %% [markdown]
# # Funciones
#
# Una función debe hacer UNA SOLA COSA y hacerla bien.

# %%
def hola():
    print("Hola mundo")

x = hola()
#print(x)
# Out:
# Hola mundo

# %%
def varios():
    return 1,'a',2,'b'

x1, x2, x3, x4 = varios()
print(x1, x2, x3, x4)
# Out:
# 1 a 2 b

# %%
def saludar(nombre: str) -> str:
    """
    Docstring

    saludar: su misión es a,msndbfasjdfkjfhqwkejfqwef

    Parámetros: nombre de tipo cadena
    
    Devuelve: Una cadena

    """

    print(f'Hola {nombre}')

    return f'Hola {nombre}'

saludar('Paco')
# Out:
# Hola Paco
# 'Hola Paco'

# %%
def parametros(uno, dos, tres,opcional=''):
    
    print(uno,dos,tres,1,2,32,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2)
    return 0

parametros(1,2,3,'nada')
# Out:
# 1 2 3 1 2 32 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
# 0

# %%
print(1,2,3)
print('otro')
# Out:
# 1 2 3
# otro

# %%
def param_variables(uno,dos,tres=1,*args,**kwargs):
    print(uno,dos,tres)

param_variables(1,2,22,2)
# Out:
# 1 2 22

# %%
def sumar(*args):
    for t in args:
        print(t, end= ' ')

datos = [999,33,221]
total = sumar(*datos)
# print(total)
# Out:
# 999 33 221

# %%
def mostrar_config(**kwargs):
    USUARIO = kwargs.get('usr','PACO')
    IP = kwargs.get('ip','127.0.0.1')
    PUERTO = kwargs.get('puerto','80')

    print(USUARIO, PUERTO,IP)


mostrar_config(usr='teo',ip='1.2.3.4', altura=1.77)
# Out:
# PACO 80 127.0.0.1

# %%
d = {
    'usr':'Teo',
    'ip':'1.2.3.4',
    'puerto':'8080'
}
mostrar_config(**d)
# Out:
# Teo 8080 1.2.3.4

# %%
def log(mensaje,*args, **kwargs):
    nivel = kwargs.get('nivel','DEBUG')
    prefijo = kwargs.get('prefijo','')
    
    msj_formato=f'[{nivel}]: {prefijo} - {mensaje}'
    return msj_formato

log("Error de configuración", nivel='ERROR')
# Out:
# '[ERROR]:  - Error de configuración'

# %%
def http_get(url, **kwargs):
    timeout = kwargs.get('timeout',5)
    headers = kwargs.get('headers',{})
    params = kwargs.get('params',{})

    return {
        'url'    : url,
        'timeout': timeout,
        'headers': headers,
        'params' : params
    }

http_get(
    'http://google.com',
    timeout=10,
    params={'page':2}
    )
# Out:
# {'url': 'http://google.com',
#  'timeout': 10,
#  'headers': {},
#  'params': {'page': 2}}
